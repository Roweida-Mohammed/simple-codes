# %% [markdown]
# <a href="https://colab.research.google.com/github/Roweida-Mohammed/simple-codes/blob/master/MLClass.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
N=50
x=np.random.rand(N)
y=np.random.rand(N)
colors=np.random.rand(N)
plt.scatter(x,y,c=colors)
plt.show()

# %%
print('My Name is Roweida Mohammed')
# Out:
# My Name is Roweida Mohammed
